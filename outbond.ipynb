# %%
import pandas as pd
from datetime import datetime
import pytz
time_zone = pytz.timezone('Asia/Kolkata')
current_time= datetime.now(time_zone)
outbond_df = pd.read_csv('ykb_outbound.csv')
outbond_df
# Out:
#     shipment_facility_current_name shipment_facility_nexthop_name  \
# 0                    MotherHub_YKB                 MotherHub_PUNE
# 1                    MotherHub_YKB                  Motherhub_PLS
# 2                    MotherHub_YKB                  Motherhub_ULB
# 3                    MotherHub_YKB              Motherhub_PAT_BTS
# 4                    MotherHub_YKB                  MotherHub_STV
# ..                             ...                            ...
# 202                  MotherHub_YKB        LoadshareLalbaghODH_MBB
# 203                  MotherHub_YKB            EnglishBazarHub_LDA
# 204                  MotherHub_YKB                  MotherHub_SIL
# 205                  MotherHub_YKB            UttamNagarMPHub_DEL
# 206                  MotherHub_YKB      GurgaonMilestoneMPHub_DEL
#
#     shipment_service_tier shipment_tms_cutoff  tracking_id_merchant  bag_id
# 0                 ECONOMY            22:00:00                  5280     204
# 1                 ECONOMY            21:00:00                  5713     203
# 2                 ECONOMY            16:00:00                  8958     404
# 3                 ECONOMY            20:00:00                  5717     329
# 4                 ECONOMY            21:00:00                  3525     109
# ..                    ...                 ...                   ...     ...
# 202               REGULAR            05:00:00                     1       1
# 203               REGULAR            06:00:00                     1       1
# 204               ECONOMY            20:00:00                     1       1
# 205               REGULAR            10:00:00                     1       1
# 206               REGULAR            11:00:00                     1       1
#
# [207 rows x 6 columns]

# %%
outbond_total = outbond_df['tracking_id_merchant'].sum()
print(f"Total Outbond:  {outbond_total}")
# Out:
# Total Outbond:  89777

# %%
outbond_xd = pd.read_csv('ykb_outbond_crossdock_abhi.csv')
outbond_xd_total = outbond_xd['tracking_id_merchant'].sum()
print(f"Total Cross-Dock Outbond:  {outbond_xd_total}")
# Out:
# Total Cross-Dock Outbond:  20254

# %%
outbond_sl = pd.read_csv('outbond_semi_large_abhi.csv')
outbond_sl_total = outbond_sl['tracking_id_merchant'].sum()
print(f"Total OutBond Semi-Large: {outbond_sl_total} ")
# Out:
# Total OutBond Semi-Large: 6600

# %%
outbond_12 = pd.read_csv("ykb_outbond_pending_greater_than_12.csv")
outbond_12
# Out:
#       shipment_facility_current_name shipment_facility_nexthop_name  \
# 0                      MotherHub_YKB       ElasticRunGuskaraODH_GKH
# 1                      MotherHub_YKB                  MotherHub_JKD
# 2                      MotherHub_YKB                  Motherhub_DIC
# 3                      MotherHub_YKB                  Motherhub_PLS
# 4                      MotherHub_YKB                JainagarHub_MDH
# ...                              ...                            ...
# 24755                  MotherHub_YKB     VxpressAsansolSplitODH_ASN
# 24756                  MotherHub_YKB     VxpressAsansolSplitODH_ASN
# 24757                  MotherHub_YKB     VxpressAsansolSplitODH_ASN
# 24758                  MotherHub_YKB     VxpressAsansolSplitODH_ASN
# 24759                  MotherHub_YKB     VxpressAsansolSplitODH_ASN
#
#       shipment_service_tier shipment_tms_cutoff tracking_id_ekart  \
# 0                   ECONOMY            04:30:00    FMPC3248992969
# 1                   ECONOMY            17:00:00    FMPC3247139180
# 2                   ECONOMY            23:00:00    FMPC3247214637
# 3                   ECONOMY            21:00:00    FMPC3249649183
# 4                   ECONOMY            20:00:00    FMPC3248158704
# ...                     ...                 ...               ...
# 24755               ECONOMY            03:00:00    FMPC3248017529
# 24756               ECONOMY            03:00:00    FMPC3249593702
# 24757               ECONOMY            03:00:00    FMPC3248361697
# 24758               ECONOMY            03:00:00    FMPP2015052145
# 24759               ECONOMY            03:00:00    FMPC3249575805
#
#       tracking_id_merchant                bag_id  \
# 0      C-69647013438887475       ERDPGKH-1351440
# 1       A-6065700436748206  EGURJJH-2828784-1558
# 2      B-47106915485035947  EHUBHUB-2441933-1322
# 3      C-26232282139870912  EGURJJH-2829041-1558
# 4      H-36069910288251632       EPATMDH-1609690
# ...                    ...                   ...
# 24755  A-54543045845888841       ERDPAST-1530781
# 24756  E-81211935139794540       ERDPAST-1530781
# 24757  C-70997460875799576       ERDPAST-1529804
# 24758   E-6234357646355248       ERDPAST-1526808
# 24759  A-70904615898250757       ERDPAST-1526808
#
#                     bag_created_time            bag_last_updated_at  \
# 0      2023-11-19T07:34:30.000+05:30  2023-11-19T07:34:30.000+05:30
# 1      2023-11-19T10:18:32.000+05:30  2023-11-19T10:18:32.000+05:30
# 2      2023-11-18T17:47:25.000+05:30  2023-11-19T05:11:52.000+05:30
# 3      2023-11-19T12:57:32.000+05:30  2023-11-19T12:57:32.000+05:30
# 4      2023-11-19T12:29:53.000+05:30  2023-11-19T12:29:53.000+05:30
# ...                              ...                            ...
# 24755  2023-11-19T07:50:34.000+05:30  2023-11-19T07:50:34.000+05:30
# 24756  2023-11-19T07:50:34.000+05:30  2023-11-19T07:50:34.000+05:30
# 24757  2023-11-19T12:37:04.000+05:30  2023-11-19T12:37:04.000+05:30
# 24758  2023-11-19T11:13:24.000+05:30  2023-11-19T11:13:24.000+05:30
# 24759  2023-11-19T11:13:24.000+05:30  2023-11-19T11:13:24.000+05:30
#
#       bag_receive_time                   sortation_layout_id  \
# 0                  NaN            171385:mh-layoutPrimaryVDS
# 1                  NaN            171385:mh-layoutPrimaryVDS
# 2                  NaN            171385:mh-layoutPrimaryCBS
# 3                  NaN            171385:mh-layoutPrimaryCBS
# 4                  NaN  171385:mh-layoutPrimaryVDS-replica-2
# ...                ...                                   ...
# 24755              NaN            171385:mh-layoutPrimaryVDS
# 24756              NaN            171385:mh-layoutPrimaryVDS
# 24757              NaN  171385:mh-layoutPrimaryVDS-replica-2
# 24758              NaN            171385:mh-layoutPrimaryVDS
# 24759              NaN            171385:mh-layoutPrimaryVDS
#
#       processing_station_current                fact_updated_at  \
# 0                     VStation11  2023-11-19T11:25:46.000+05:30
# 1                     VStation12  2023-11-19T10:18:32.000+05:30
# 2                    NZStation20  2023-11-19T05:11:52.000+05:30
# 3                    NZStation20  2023-11-19T12:57:32.000+05:30
# 4            VStation9-replica-2  2023-11-19T12:29:53.000+05:30
# ...                          ...                            ...
# 24755                 VStation11  2023-11-19T07:50:34.000+05:30
# 24756                 VStation11  2023-11-19T07:55:34.000+05:30
# 24757       VStation11-replica-2  2023-11-19T12:37:04.000+05:30
# 24758                 VStation11  2023-11-19T11:13:24.000+05:30
# 24759                 VStation11  2023-11-19T11:13:24.000+05:30
#
#       shipment_status bag_status bag_facility_source_name  \
# 0        added_to_bag     CLOSED            MotherHub_YKB
# 1        added_to_bag     CLOSED            MotherHub_YKB
# 2        added_to_bag     CLOSED            MotherHub_YKB
# 3        added_to_bag     CLOSED            MotherHub_YKB
# 4        added_to_bag     CLOSED            MotherHub_YKB
# ...               ...        ...                      ...
# 24755    added_to_bag     CLOSED            MotherHub_YKB
# 24756    added_to_bag     CLOSED            MotherHub_YKB
# 24757    added_to_bag     CLOSED            MotherHub_YKB
# 24758    added_to_bag     CLOSED            MotherHub_YKB
# 24759    added_to_bag     CLOSED            MotherHub_YKB
#
#       shipment_facility_source_name                   shipment_cpd
# 0                     MotherHub_YKB  2023-11-23T02:59:59.000+05:30
# 1                     MotherHub_YKB  2023-11-27T02:59:59.000+05:30
# 2                     Motherhub_DIC  2023-11-26T02:59:59.000+05:30
# 3                     MotherHub_YKB  2023-11-29T02:59:59.000+05:30
# 4                     MotherHub_YKB  2023-11-27T02:59:59.000+05:30
# ...                             ...                            ...
# 24755                 MotherHub_YKB  2023-11-23T02:59:59.000+05:30
# 24756                 MotherHub_YKB  2023-11-24T02:59:59.000+05:30
# 24757                 MotherHub_YKB  2023-11-23T02:59:59.000+05:30
# 24758                 MotherHub_YKB  2023-11-24T02:59:59.000+05:30
# 24759                 MotherHub_YKB  2023-11-25T02:59:59.000+05:30
#
# [24760 rows x 18 columns]

# %%
def calculate_and_categorize_time(dataframe, column_name, current_time  , bucket_name):
    df_time_wise = pd.to_datetime(dataframe[column_name])
    df_hour_wise = (current_time - df_time_wise) / pd.Timedelta(hours=1)
    df_hour_wise = df_hour_wise.round().astype(int)
    
    def categorize_time(hour_diff):
        if hour_diff > 48:
            return '> 48 hours'
        elif hour_diff > 24 and hour_diff < 48:
            return '24-48 hours'
        elif hour_diff > 12:
            return '12-24 hours'
        else:
            return '< 12 hours'
    
    dataframe["hour_diff"] = df_hour_wise
    dataframe[bucket_name] = df_hour_wise.apply(categorize_time)
    data = dataframe[bucket_name].value_counts()
    return data


outbond_12_pendency = calculate_and_categorize_time(outbond_12 , 'fact_updated_at' , current_time , "Outbond Pendency")
